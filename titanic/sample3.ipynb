# %%
#https://www.kaggle.com/scirpus/genetic-programming-lb-0-88/code
#参考
#http://www.genetic-programming.org/
#http://www.tc33.org/genetic-programming/genetic-programming-software-comparison/
import numpy as np
import pandas as pd
import operator
import operator as sub
import operator as mul
import operator as neg
import operator as add

import math as cos
import math as sin

# %%
def protectedDiv(left, right):
        try:
            return left / right
        except ZeroDivisionError:
            return 1

def Outputs(data):
    return np.round(1.-(1./(1.+np.exp(-data))))

# %% [markdown]
# 数値の文字列は、さまざまなパラメータを持つ遺伝子プログラムを自分で実行するツリーの結果です。
#
# - 人口の大きさ
# - 世代
# - 最大の成長のために作られた樹木
# - 部分成長のために作られた樹木
# - 関数セット（+、 - 、sin、cosなどの演算子）
# - ターミナルセット
# - 適応度の程度（二乗誤差など）
# - 等...
#
# ツリーは、異なる計算優先順位（ツリーによって定義される）を持つ関数（+、 - 、sin ...）の合成
# 1000世代後に進化した最高の個体の成果

# %%
def GeneticFunction(data):
    return (
#         sub(mul(max(neg(add(add(min(protectedDiv(cos(max(x6, mul(protectedDiv(cos(x5), max(cos(mul(sin(x6), x4)), -1.9640506881826774)), x5))), max(cos(add(add(protectedDiv(min(x5, cos(protectedDiv(x7, neg(x4)))), x8), add(x8, cos(x3))), sin(neg(mul(mul(x6, x3), sin(max(x3, x6))))))), min(protectedDiv(cos(-1.2916830237199388), max(cos(mul(x1, mul(x4, x4))), -1.9640506881826774)), x7))), add(x7, x4)), add(mul(x3, x8), x1)), x7)), x2), add(x2, mul(neg(cos(x7)), min(min(x7, min(min(sub(x8, mul(mul(sin(mul(sin(x7), max(neg(x4), x6))), max(cos(cos(x7)), -1.9640506881826774)), add(x8, cos(x3)))), add(add(x5, add(max(protectedDiv(max(protectedDiv(x7, add(x4, x6)), sub(cos(x4), mul(max(x1, x5), sin(x3)))), mul(sin(mul(x8, max(x8, x6))), sub(x5, x1))), protectedDiv(mul(mul(x3, x6), x5), x5)), cos(x3))), sin(neg(mul(mul(mul(x3, x8), x3), sin(protectedDiv(max(x3, x8), min(x8, x6)))))))), max(mul(max(sin(x6), x3), add(cos(cos(add(x5, sin(x7)))), mul(sin(max(sub(neg(x2), sub(x7, 8.760459498320127)), x3)), x5))), sub(max(sub(protectedDiv(sub(protectedDiv(sub(x4, x5), x8), sin(sin(mul(x8, max(x8, x6))))), mul(sin(mul(sin(x7), max(x3, x6))), max(cos(cos(x5)), -1.9640506881826774))), protectedDiv(sin(x7), neg(x5))), sub(max(x2, x4), x8)), x7)))), min(min(max(neg(sub(x5, x4)), protectedDiv(x7, protectedDiv(add(add(x2, sub(x6, 8.760459498320127)), x5), min(x6, x8)))), add(add(protectedDiv(min(x5, cos(protectedDiv(x7, neg(x4)))), x8), add(x8, cos(x3))), sin(neg(mul(mul(x6, x3), sin(max(x3, x6))))))), max(mul(max(mul(neg(x1), sub(mul(protectedDiv(mul(x5, x6), x3), sin(neg(mul(mul(x6, x3), sin(max(x3, x6)))))), mul(sin(x7), mul(min(sub(protectedDiv(x4, x1), cos(x4)), x8), sub(add(x2, sub(x6, 8.760459498320127)), x7))))), sin(neg(mul(mul(x3, x3), sin(protectedDiv(max(x3, neg(x4)), min(x8, x7))))))), mul(x6, x7)), x5)))))), cos(mul(min(add(protectedDiv(protectedDiv(add(add(min(protectedDiv(sub(neg(sub(x8, x7)), x1), x8), x3), add(x7, x5)), x3), protectedDiv(add(x8, x2), x8)), x4), add(add(protectedDiv(x5, add(max(neg(mul(x3, x1)), mul(min(protectedDiv(cos(max(x6, sin(protectedDiv(x5, x8)))), max(cos(mul(x4, x4)), -1.9640506881826774)), protectedDiv(add(sin(mul(mul(x3, x6), x3)), protectedDiv(8.760459498320127, x5)), x5)), x4)), sin(mul(neg(x8), sub(x1, mul(sin(x7), mul(min(sub(protectedDiv(x4, x8), cos(x5)), x8), x5))))))), add(x8, cos(x3))), sin(sub(protectedDiv(2.174165091426394, x6), max(x6, x2))))), max(sub(max(sub(protectedDiv(sub(add(max(min(sin(sub(sub(cos(x5), x8), mul(x4, x4))), sub(x8, x1)), x1), cos(protectedDiv(mul(cos(cos(x5)), mul(x4, x5)), x4))), x8), x5), sin(sin(mul(x3, x6)))), mul(cos(x5), max(x7, mul(cos(x5), mul(x4, x4))))), x7), min(x8, max(sub(max(sub(protectedDiv(sub(x7, x8), x5), min(min(x1, min(x5, add(max(mul(x2, x1), x1), x3))), x6)), neg(add(max(mul(x2, x1), x1), mul(x8, x5)))), protectedDiv(sub(add(protectedDiv(add(add(neg(x5), x8), sin(sub(sub(cos(x5), x8), mul(x4, x4)))), x4), x8), x8), x7)), sub(max(protectedDiv(cos(-1.2916830237199388), max(cos(mul(x1, mul(x4, x4))), sin(x3))), x1), x7))))), cos(cos(mul(x5, cos(mul(x1, cos(cos(cos(mul(sin(mul(x7, mul(min(mul(x3, x7), x3), cos(sin(x1))))), max(protectedDiv(add(x2, x7), add(x7, mul(mul(x1, -0.22815663898285976), cos(-6.285984927335305)))), max(9.746784212885991, x1))))))))))))))
#                 sub(mul(max(neg(add(add(min(protectedDiv(cos(max(data["Fare"], mul(protectedDiv(cos(data["Parch"]), max(cos(mul(sin(data["Fare"]), data["SibSp"])), -1.9640506881826774)), data["Parch"]))), max(cos(add(add(protectedDiv(min(data["Parch"], cos(protectedDiv(data["Cabin"], neg(data["SibSp"])))), data["Embarked"]), add(data["Embarked"], cos(data["Age"]))), sin(neg(mul(mul(data["Fare"], data["Age"]), sin(max(data["Age"], data["Fare"]))))))), min(protectedDiv(cos(-1.2916830237199388), max(cos(mul(data["Pclass"], mul(data["SibSp"], data["SibSp"]))), -1.9640506881826774)), data["Cabin"]))), add(data["Cabin"], data["SibSp"])), add(mul(data["Age"], data["Embarked"]), data["Pclass"])), data["Cabin"])), data["Sex"]), add(data["Sex"], mul(neg(cos(data["Cabin"])), min(min(data["Cabin"], min(min(sub(data["Embarked"], mul(mul(sin(mul(sin(data["Cabin"]), max(neg(data["SibSp"]), data["Fare"]))), max(cos(cos(data["Cabin"])), -1.9640506881826774)), add(data["Embarked"], cos(data["Age"])))), add(add(data["Parch"], add(max(protectedDiv(max(protectedDiv(data["Cabin"], add(data["SibSp"], data["Fare"])), sub(cos(data["SibSp"]), mul(max(data["Pclass"], data["Parch"]), sin(data["Age"])))), mul(sin(mul(data["Embarked"], max(data["Embarked"], data["Fare"]))), sub(data["Parch"], data["Pclass"]))), protectedDiv(mul(mul(data["Age"], data["Fare"]), data["Parch"]), data["Parch"])), cos(data["Age"]))), sin(neg(mul(mul(mul(data["Age"], data["Embarked"]), data["Age"]), sin(protectedDiv(max(data["Age"], data["Embarked"]), min(data["Embarked"], data["Fare"])))))))), max(mul(max(sin(data["Fare"]), data["Age"]), add(cos(cos(add(data["Parch"], sin(data["Cabin"])))), mul(sin(max(sub(neg(data["Sex"]), sub(data["Cabin"], 8.760459498320127)), data["Age"])), data["Parch"]))), sub(max(sub(protectedDiv(sub(protectedDiv(sub(data["SibSp"], data["Parch"]), data["Embarked"]), sin(sin(mul(data["Embarked"], max(data["Embarked"], data["Fare"]))))), mul(sin(mul(sin(data["Cabin"]), max(data["Age"], data["Fare"]))), max(cos(cos(data["Parch"])), -1.9640506881826774))), protectedDiv(sin(data["Cabin"]), neg(data["Parch"]))), sub(max(data["Sex"], data["SibSp"]), data["Embarked"])), data["Cabin"])))), min(min(max(neg(sub(data["Parch"], data["SibSp"])), protectedDiv(data["Cabin"], protectedDiv(add(add(data["Sex"], sub(data["Fare"], 8.760459498320127)), data["Parch"]), min(data["Fare"], data["Embarked"])))), add(add(protectedDiv(min(data["Parch"], cos(protectedDiv(data["Cabin"], neg(data["SibSp"])))), data["Embarked"]), add(data["Embarked"], cos(data["Age"]))), sin(neg(mul(mul(data["Fare"], data["Age"]), sin(max(data["Age"], data["Fare"]))))))), max(mul(max(mul(neg(data["Pclass"]), sub(mul(protectedDiv(mul(data["Parch"], data["Fare"]), data["Age"]), sin(neg(mul(mul(data["Fare"], data["Age"]), sin(max(data["Age"], data["Fare"])))))), mul(sin(data["Cabin"]), mul(min(sub(protectedDiv(data["SibSp"], data["Pclass"]), cos(data["SibSp"])), data["Embarked"]), sub(add(data["Sex"], sub(data["Fare"], 8.760459498320127)), data["Cabin"]))))), sin(neg(mul(mul(data["Age"], data["Age"]), sin(protectedDiv(max(data["Age"], neg(data["SibSp"])), min(data["Embarked"], data["Cabin"]))))))), mul(data["Fare"], data["Cabin"])), data["Parch"])))))), cos(mul(min(add(protectedDiv(protectedDiv(add(add(min(protectedDiv(sub(neg(sub(data["Embarked"], data["Cabin"])), data["Pclass"]), data["Embarked"]), data["Age"]), add(data["Cabin"], data["Parch"])), data["Age"]), protectedDiv(add(data["Embarked"], data["Sex"]), data["Embarked"])), data["SibSp"]), add(add(protectedDiv(data["Parch"], add(max(neg(mul(data["Age"], data["Pclass"])), mul(min(protectedDiv(cos(max(data["Fare"], sin(protectedDiv(data["Parch"], data["Embarked"])))), max(cos(mul(data["SibSp"], data["SibSp"])), -1.9640506881826774)), protectedDiv(add(sin(mul(mul(data["Age"], data["Fare"]), data["Age"])), protectedDiv(8.760459498320127, data["Parch"])), data["Parch"])), data["SibSp"])), sin(mul(neg(data["Embarked"]), sub(data["Pclass"], mul(sin(data["Cabin"]), mul(min(sub(protectedDiv(data["SibSp"], data["Embarked"]), cos(data["Parch"])), data["Embarked"]), data["Parch"]))))))), add(data["Embarked"], cos(data["Age"]))), sin(sub(protectedDiv(2.174165091426394, data["Fare"]), max(data["Fare"], data["Sex"]))))), max(sub(max(sub(protectedDiv(sub(add(max(min(sin(sub(sub(cos(data["Parch"]), data["Embarked"]), mul(data["SibSp"], data["SibSp"]))), sub(data["Embarked"], data["Pclass"])), data["Pclass"]), cos(protectedDiv(mul(cos(cos(data["Parch"])), mul(data["SibSp"], data["Parch"])), data["SibSp"]))), data["Embarked"]), data["Parch"]), sin(sin(mul(data["Age"], data["Fare"])))), mul(cos(data["Parch"]), max(data["Cabin"], mul(cos(data["Parch"]), mul(data["SibSp"], data["SibSp"]))))), data["Cabin"]), min(data["Embarked"], max(sub(max(sub(protectedDiv(sub(data["Cabin"], data["Embarked"]), data["Parch"]), min(min(data["Pclass"], min(data["Parch"], add(max(mul(data["Sex"], data["Pclass"]), data["Pclass"]), data["Age"]))), data["Fare"])), neg(add(max(mul(data["Sex"], data["Pclass"]), data["Pclass"]), mul(data["Embarked"], data["Parch"])))), protectedDiv(sub(add(protectedDiv(add(add(neg(data["Parch"]), data["Embarked"]), sin(sub(sub(cos(data["Parch"]), data["Embarked"]), mul(data["SibSp"], data["SibSp"])))), data["SibSp"]), data["Embarked"]), data["Embarked"]), data["Cabin"])), sub(max(protectedDiv(cos(-1.2916830237199388), max(cos(mul(data["Pclass"], mul(data["SibSp"], data["SibSp"]))), sin(data["Age"]))), data["Pclass"]), data["Cabin"]))))), cos(cos(mul(data["Parch"], cos(mul(data["Pclass"], cos(cos(cos(mul(sin(mul(data["Cabin"], mul(min(mul(data["Age"], data["Cabin"]), data["Age"]), cos(sin(data["Pclass"]))))), max(protectedDiv(add(data["Sex"], data["Cabin"]), add(data["Cabin"], mul(mul(data["Pclass"], -0.22815663898285976), cos(-6.285984927335305)))), max(9.746784212885991, data["Pclass"]))))))))))))))
            (np.minimum( ((((0.058823499828577 + data["Sex"]) - np.cos((data["Pclass"] / 2.0))) * 2.0)),  ((0.885868))) * 2.0)
           + np.maximum( ((data["SibSp"] - 2.409090042114258)) ,  ( -(np.minimum( (data["Sex"]) ,  (np.sin(data["Parch"]))) * data["Pclass"]))) 
           + (0.138462007045746 * ((np.minimum( (data["Sex"])
            ,  (((data["Parch"] / 2.0) / 2.0))) * data["Age"]) - data["Cabin"])) +
            np.minimum( ((np.sin((data["Parch"] * ((data["Fare"] - 0.720430016517639) * 2.0))) * 2.0))
            ,  ((data["SibSp"] / 2.0))) +
            np.maximum( (np.minimum( ( -np.cos(data["Embarked"]))
            ,  (0.138462007045746)))
            ,  (np.sin(((data["Cabin"] - data["Fare"]) * 2.0)))) + -np.minimum( ((((data["Age"] * data["Parch"]) * data["Embarked"]) + data["Parch"]))
            ,  (np.sin(data["Pclass"]))) +
            np.minimum( (data["Sex"]),  ((np.sin( -(data["Fare"] * np.cos((data["Fare"] * 1.630429983139038)))) / 2.0))) +
            np.minimum( ((0.230145)),  (np.sin(np.minimum( (((67.0 / 2.0) * np.sin(data["Fare"]))),  (0.31830988618379069))))) +
            np.sin((np.sin(data["Cabin"]) * (np.sin((12.6275)) * np.maximum( (data["Age"]),  (data["Fare"]))))) +
            np.sin(((np.minimum( (data["Fare"]),  ((data["Cabin"] * data["Embarked"]))) / 2.0) *  -data["Fare"])) +
            np.minimum( (((2.675679922103882 * data["SibSp"]) * np.sin(((96) * np.sin(data["Cabin"]))))),  (data["Parch"])) +
            np.sin(np.sin((np.maximum( (np.minimum( (data["Age"]),  (data["Cabin"]))),  ((data["Fare"] * 0.31830988618379069))) * data["Cabin"]))) +
            np.maximum( (np.sin(((12.4148) * (data["Age"] / 2.0)))),  (np.sin((-3.0 * data["Cabin"])))) +
            (np.minimum( (np.sin((((np.sin(((data["Fare"] * 2.0) * 2.0)) * 2.0) * 2.0) * 2.0))),  (data["SibSp"])) / 2.0) +
            ((data["Sex"] - data["SibSp"]) * (np.cos(((data["Embarked"] - 0.730768978595734) + data["Age"])) / 2.0)) +
            ((np.sin(data["Cabin"]) / 2.0) - (np.cos(np.minimum( (data["Age"]),  (data["Embarked"]))) * np.sin(data["Embarked"]))) +
            np.minimum( (0.31830988618379069),  ((data["Sex"] * (2.212120056152344 * (0.720430016517639 - np.sin((data["Age"] * 2.0))))))) +
            (np.minimum( (np.cos(data["Fare"])),  (np.maximum( (np.sin(data["Age"])),  (data["Parch"])))) * np.cos((data["Fare"] / 2.0))) +
            np.sin((data["Parch"] * np.minimum( ((data["Age"] - 1.5707963267948966)),  ((np.cos((data["Pclass"] * 2.0)) / 2.0))))) +
            (data["Parch"] * (np.sin(((data["Fare"] * (0.623655974864960 * data["Age"])) * 2.0)) / 2.0)) +
            (0.31830988618379069 * np.cos(np.maximum( ((0.602940976619720 * data["Fare"])),  ((np.sin(0.720430016517639) * data["Age"]))))) +
            (np.minimum( ((data["SibSp"] / 2.0)),  (np.sin(((data["Pclass"] - data["Fare"]) * data["SibSp"])))) * data["SibSp"]) +
            np.tanh((data["Sex"] * np.sin((5.199999809265137 * np.sin((data["Cabin"] * np.cos(data["Fare"]))))))) +
            (np.minimum( (data["Parch"]),  (data["Sex"])) * np.cos(np.maximum( ((np.cos(data["Parch"]) + data["Age"])),  (3.1415926535897931)))) +
            (np.minimum( (np.tanh(((data["Cabin"] / 2.0) + data["Parch"]))),  ((data["Sex"] + np.cos(data["Age"])))) / 2.0) +
            (np.sin((np.sin(data["Sex"]) * (np.sin((data["Age"] * data["Pclass"])) * data["Pclass"]))) / 2.0) +
            (data["Sex"] * (np.cos(((data["Sex"] + data["Fare"]) * ((8.48635) * (63)))) / 2.0)) +
            np.minimum( (data["Sex"]),  ((np.cos((data["Age"] * np.tanh(np.sin(np.cos(data["Fare"]))))) / 2.0))) +
            (np.tanh(np.tanh( -np.cos((np.maximum( (np.cos(data["Fare"])),  (0.094339601695538)) * data["Age"])))) / 2.0) +
            (np.tanh(np.cos((np.cos(data["Age"]) + (data["Age"] + np.minimum( (data["Fare"]),  (data["Age"])))))) / 2.0) +
            (np.tanh(np.cos((data["Age"] * ((-2.0 + np.sin(data["SibSp"])) + data["Fare"])))) / 2.0) +
            (np.minimum( (((281) - data["Fare"])),  (np.sin((np.maximum( ((176)),  (data["Fare"])) * data["SibSp"])))) * 2.0) +
            np.sin(((np.maximum( (data["Embarked"]),  (data["Age"])) * 2.0) * (((785) * 3.1415926535897931) * data["Age"]))) +
            np.minimum( (data["Sex"]),  (np.sin( -(np.minimum( ((data["Cabin"] / 2.0)),  (data["SibSp"])) * (data["Fare"] / 2.0))))) +
            np.sin(np.sin((data["Cabin"] * (data["Embarked"] + (np.tanh( -data["Age"]) + data["Fare"]))))) +
            (np.cos(np.cos(data["Fare"])) * (np.sin((data["Embarked"] - ((734) * data["Fare"]))) / 2.0)) +
            ((np.minimum( (data["SibSp"]),  (np.cos(data["Fare"]))) * np.cos(data["SibSp"])) * np.sin((data["Age"] / 2.0))) +
            (np.sin((np.sin((data["SibSp"] * np.cos((data["Fare"] * 2.0)))) + (data["Cabin"] * 2.0))) / 2.0) +
            (((data["Sex"] * data["SibSp"]) * np.sin(np.sin( -(data["Fare"] * data["Cabin"])))) * 2.0) +
            (np.sin((data["SibSp"] * ((((5.428569793701172 + 67.0) * 2.0) / 2.0) * data["Age"]))) / 2.0) +
            (data["Pclass"] * (np.sin(((data["Embarked"] * data["Cabin"]) * (data["Age"] - (1.07241)))) / 2.0)) +
            (np.cos((((( -data["SibSp"] + data["Age"]) + data["Parch"]) * data["Embarked"]) / 2.0)) / 2.0) +
            (0.31830988618379069 * np.sin(((data["Age"] * ((data["Embarked"] * np.sin(data["Fare"])) * 2.0)) * 2.0))) +
            ((np.minimum( ((data["Age"] * 0.058823499828577)),  (data["Sex"])) - 0.63661977236758138) * np.tanh(np.sin(data["Pclass"]))) +
            -np.minimum( ((np.cos(((727) * ((data["Fare"] + data["Parch"]) * 2.0))) / 2.0)),  (data["Fare"])) +
            (np.minimum( (np.cos(data["Fare"])),  (data["SibSp"])) * np.minimum( (np.sin(data["Parch"])),  (np.cos((data["Embarked"] * 2.0))))) +
            (np.minimum( (((data["Fare"] / 2.0) - 2.675679922103882)),  (0.138462007045746)) * np.sin((1.5707963267948966 * data["Age"]))) +
            np.minimum( ((0.0821533)),  (((np.sin(data["Fare"]) + data["Embarked"]) - np.cos((data["Age"] * (9.89287))))))
    )

# %%
def MungeData(data):
    # Sex
    data.drop(['Ticket', 'Name'], inplace=True, axis=1)
    data.Sex.fillna('0', inplace=True)
    data.loc[data.Sex != 'male', 'Sex'] = 0
    data.loc[data.Sex == 'male', 'Sex'] = 1
    # Cabin
    data.Cabin.fillna('0', inplace=True)
    data.loc[data.Cabin.str[0] == 'A', 'Cabin'] = 1
    data.loc[data.Cabin.str[0] == 'B', 'Cabin'] = 2
    data.loc[data.Cabin.str[0] == 'C', 'Cabin'] = 3
    data.loc[data.Cabin.str[0] == 'D', 'Cabin'] = 4
    data.loc[data.Cabin.str[0] == 'E', 'Cabin'] = 5
    data.loc[data.Cabin.str[0] == 'F', 'Cabin'] = 6
    data.loc[data.Cabin.str[0] == 'G', 'Cabin'] = 7
    data.loc[data.Cabin.str[0] == 'T', 'Cabin'] = 8
    # Embarked
    data.loc[data.Embarked == 'C', 'Embarked'] = 1
    data.loc[data.Embarked == 'Q', 'Embarked'] = 2
    data.loc[data.Embarked == 'S', 'Embarked'] = 3
    data.Embarked.fillna(0, inplace=True)
    data.fillna(-1, inplace=True)
    return data.astype(float)

# %%
if __name__ == "__main__":
    train = pd.read_csv('./train.csv')
    test = pd.read_csv('./test.csv')
    mungedtrain = MungeData(train)
    trainPredictions = Outputs(GeneticFunction(mungedtrain))

    print(trainPredictions.head(3))
    pdtrain = pd.DataFrame({'PassengerId': mungedtrain.PassengerId.astype(int),
                            'Predicted': trainPredictions.astype(int),
                            'Survived': mungedtrain.Survived.astype(int)})
    pdtrain.to_csv('gptrain.csv', index=False)
    mungedtest = MungeData(test)
    testPredictions = Outputs(GeneticFunction(mungedtest))

    pdtest = pd.DataFrame({'PassengerId': mungedtest.PassengerId.astype(int),
                            'Survived': testPredictions.astype(int)})
    pdtest.to_csv('sample3.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ce986f60bd2a> in <module>()
#       3     test = pd.read_csv('./test.csv')
#       4     mungedtrain = MungeData(train)
# ----> 5     trainPredictions = Outputs(GeneticFunction(mungedtrain))
#       6
#       7     print(trainPredictions.head(3))
#
# <ipython-input-42-391025884858> in GeneticFunction(data)
#       2     return (
# ...
