# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
plt.style.use('ggplot')

# %% [markdown]
# 参考
# http://bicycle1885.hatenablog.com/entry/2014/02/14/023734

# %%
n = 1000
np.random.seed(100)
x = randn(n) # 標準正規分布で乱数を1000個生成
plt.hist(x ,bins=100) # 100本のヒストグラムを作成
plt.show()

# %%
x = np.arange(-3, 3, 0.1)
y = np.sin(x)
plt.plot(x, y)
